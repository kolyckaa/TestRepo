# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, we will explore some of the languages, libraries, and tools used in data science.

# %% [markdown]
# **Objectives:**
# - List popular languages for Data Science
# - List commonly used libraries
# - Demonstrate arithmetic expressions in Python

# %% [markdown]
# **Author: Lina Melcharek**

# %% [markdown]
# **Popular Data Science Languages:**
# - Python
# - R
# - SQL

# %% [markdown]
# **Common Data Science Libraries:**
# - Pandas
# - NumPy
# - Matplotlib

# %% [markdown]
# | Tool | Category |
# |------|----------|
# | Jupyter Notebook | IDE |
# | RStudio | IDE |
# | Tableau | Data Visualization |

# %% [markdown]
# ### Examples of Arithmetic Expressions in Python
# Below are simple examples of how to multiply and add numbers in Python.

# %%
# This a simple arithmetic expression to multiply then add integers
result_multiply = (3 * 4) + 5 
result_multiply
# Out:
# 17

# %%
minutes = 120
hours = minutes / 60
hours
# This will convert 200 minutes to hours by diving by 60.
# Out:
# 2.0
